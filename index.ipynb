# %%
from ipyturtle import Turtle
from IPython.display import display

# Turtle erstellen
t = Turtle()
display(t)  # unbedingt notwendig in Notebook 6+

# Beispielbewegungen
t.forward(100)
t.left(90)
t.forward(50)
t.right(45)
t.forward(70)
